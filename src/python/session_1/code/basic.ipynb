# %%
print("My name is {f} and I am {a} years old".format(f="Farida", a=20))
# Out:
# My name is Farida and I am 20 years old

# %%
name = "Farida"
age = 20
coursename = "ML"
print(f"My name is {name}, and I am {age} years old. I am engaged in learning {coursename}")
# Out:
# My name is Farida, and I am 20 years old. I am engaged in learning ML

# %%
x = True
type(x)
# Out:
# bool

# %%
name = "depi r4"
print(name[-1])
# Out:
# 4

# %%
name = "amit learning"
print(name[5:13:1])
# Out:
# learning

# %%
name = "farida"
print(name.upper())
# Out:
# DIDA

# %%
name = "FARIDA"
print(name.lower)

# %%
name = "farida"
print(name.capitalize())
# Out:
# Farida

# %%
msg = "Hi Farida"
print(msg.replace("Hi", "Hello"))
# Out:
# Hello Farida

# %%
msg2 = "welcome to depi r4"
splitmsg = msg2.split() #takes every word tkhleha token
splitmsg #ethawlet l list (string >> ist)
print(type(splitmsg)) #bttl3 el type bta3ha which is list
# Out:
# <class 'list'>

# %%
sentence = " ".join(splitmsg) #returns the list to a normal string
sentence
# Out:
# 'welcome to depi r4'

# %%
msg2 = "welcome to depi r4"
print(name.endswith(".")) #checks if the string ends with smmth
# Out:
# False

# %%
print("use \t to leave a space")
print("use \n to make a new line")
print("this is a double quote \"hello\"")
print("hello\b")
# Out:
# use 	 to leave a space
# use
#  to make a new line
# this is a double quote "hello"
# hell

# %%
len(name)
# Out:
# 6

# %%
s = "depi"
x = "hey"
s
x
s
# Out:
# 'depi'

# %%
x = 2
print(hex(id(x)))
# Out:
# 0x7ffbd3d973c8

# %%
"x" in "xavier"
# Out:
# True

# %%
s = "welcome to depi"
s.find("depi")
# Out:
# 11

# %%
s = "          depi   "
s.strip()
# Out:
# 'depi'
