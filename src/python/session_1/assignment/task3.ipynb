# %%
msg = "&&&**$gnirtS PLIO!!@1234 "
extracted = msg[6:17]
print(extracted)
# Out:
# gnirtS PLIO

# %%
#step2
word1 = extracted.split()[0]
word1_reversed = word1[::-1]
print(word1_reversed)
# Out:
# String

# %%
#step3
word2 = extracted.split()[1]
word2_replced = word2.replace("I", "E").replace("O","U")
print(word2_replced)
# Out:
# PLEU

# %%
#final
decoded = word1_reversed + " " + word2_replced
print(decoded)
# Out:
# String PLEU
