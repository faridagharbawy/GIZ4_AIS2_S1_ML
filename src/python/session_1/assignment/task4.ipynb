# %%
#step1:
msg = "##$$$@!yalpstcejorp EPUVT****9887"
extracted = msg[7:25]
print(extracted)
# Out:
# yalpstcejorp EPUVT

# %%
#step2:
word1 = extracted.split()[0]
word1_reversed = word1[::-1]
print(word1_reversed)
# Out:
# projectsplay

# %%
#step3
word2 = extracted.split()[1]
word2_replaced = word2.replace("E","A").replace("U","O")
print(word2_replaced)
# Out:
# APOVT

# %%
#step4
decoded = word1_reversed + " " + word2_replaced
print(decoded)
# Out:
# projectsplay APOVT
