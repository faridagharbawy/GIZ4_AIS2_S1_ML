# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    
    @abstractmethod
    def move(self):
        pass
    
class Bird(Animal):
    # def move(self):
    # print("Bird")
        pass
        
class Cat(Animal):
    def move(self):
        print("cat")

# %%
a = Bird()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a = Bird()
#
# TypeError: Can't instantiate abstract class Bird without an implementation for abstract method 'move'

# %%
class A():
    def do_this(self):
        print("A")
        
class B(A):
    pass

class C():
    def do_this(self):
        print("C")
        
class D(C,B):
    pass

x = D()
x.do_this()
# Out:
# C

# %%
try:
    5/0
except:
    print("unable to divide by zero")
# Out:
# unable to divide by zero

# %%
try:
    x =10
    y = int(input())
    x/y
    
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
import os
base = "D:/depi/GIZ4_AIS2_S1_ML/src/python/session_5/code"
type(base)
# Out:
# str

# %%
file = os.listdir(base)
print(file)
# Out:
# ['basic.ipynb', 'test.txt']

# %%
os.remove(base+ "/test.txt")
file = os.listdir(base)
print(file)
# Out:
# ['basic.ipynb']

# %%
import os

directory = "./directory_test"

if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("Directory already exists", directory)
# Out:
# Directory already exists ./directory_test

# %%
import os

path = "temp_dir"

if not os.path.exists(path):
    os.makedirs(path)
for i in range(20):
    inner_path = os.path.join(path, "dir_" + str(i+1))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)

# %%
import os
def create_folder(path):
    path = "temp_dir"

    if not os.path.exists(path):
        os.makedirs(path)
    for i in range(20):
        inner_path = os.path.join(path, "dir_" + str(i+1))
        if not os.path.exists(inner_path):
            os.makedirs(inner_path)

# %%
if __name__ == "__main__":
    path = "D:/depi/GIZ4_AIS2_S1_ML/src/python/session_5/code"
    create_folder(path)

# %%
with open("./temp_dir/text1.txt", "a+") as file:
    file.write("New line added\n")
    file.seek(0)
    update_content = file.read()
    print(update_content)
# Out:
# New line added

# %%
! pip install prettytable
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random 

from prettytable import PrettyTable
u = "test"
p = "1111"
while True :
    x = input("Enter your name")
    if x == u:
        y = input("enter your password")
        if y == p : 
            s = random.randrange(10000 , 1000000)
            print("Verification code is " , s)
            while True : 
                l = int(input("Enter your verification code"))
                if l == s : 
                    print("Access Granted!")
                    break 
                else :
                    print("Invalid verification code. please try again. ")
            break 
        else:
            print("incorrect password. please try again.")
            continue          
    else :
        print("Incorrect username. please try again.")
        continue
# Out:
# Verification code is  35596
# Access Granted!
