# %%
#list :
# ordered data (ht3aml maa data) 
# CHANGEABLE 
# allows duplicate data
# obara aan row list. 
# its represetned by []
# nested among all(common fkolo) 
x= "farida"
list(x)
# Out:
# ['f', 'a', 'r', 'i', 'd', 'a']

# %%
#tuple
# ordered data (ht3aml maa data) 
# UNCHANGEABLE >> meza, law ayza aghyr ahwlha l list then aghyr then arg3ha l tuple tany
# allows duplicate data 
# its represetned by ()
# nested among all(common fkolo)

# %%
#set
# unordered data (ht3aml maa data) >btkhdm ala el probability ans possibilty distribution 
# UNCHANGEABLE >> meza 
# DOESNT allow duplicate data (used in NLP)
# its represetned by {}
# nested among all(common fkolo) 
x = "farida"
set(x) #msh ordered
# Out:
# {'a', 'd', 'f', 'i', 'r'}

# %%
#dictionary :
# ordered data (ht3aml maa data) 
# CHANGEABLE 
# DOESNT ALLOW duplicate for keys 
# its represetned by {}
# nested among all(common fkolo)

# %%
list_one = [1,2,3,4,"DEPI","learning",True,[1,2,3,"True",["ml","dl","ds"]]]
type(list_one)
list_one[7][1] = "depiii"
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'DEPI',
#  'learning',
#  True,
#  [1, 'depiii', 3, 'True', ['ml', 'dl', 'ds']]]

# %%
list_two = ["amit", "learning", "python"]
list_two.append("ml") #append bt add flakher
print(list_two)
# Out:
# ['amit', 'learning', 'python', 'ml']

# %%
list_two.insert(0,"depi") #insert btbdl haga at specific index b haga tnya
print(list_two)
# Out:
# ['depi', 'amit', 'learning', 'python', 'ml']

# %%
list1 = [1,2,3]
list2 = [4,5,6]
list1.extend(list2) #extend btmerge 2 lists swa
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_two = ["amit", "learning", "python"]
list_two.remove("python")
print(list_two)
# Out:
# ['amit', 'learning']

# %%
list_two = ["amit", "learning", "python"]
list_two.pop()
print(list_two)
# Out:
# ['amit', 'learning']

# %%
list_two = ["amit", "learning", "python"]
list_two.pop(0)
print(list_two)
# Out:
# ['learning', 'python']

# %%
del(list_two)
print(list_two)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 del(list_two)
#       2 print(list_two)
#
# NameError: name 'list_two' is not defined

# %%
list3 = [1,2,3]
list3*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
len(list3)
# Out:
# 3

# %%
list4 = ["ml","depi","amit","r4"]
x = input("enter index")
list4.remove(x)
print(list4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 list4 = ["ml","depi","amit","r4"]
#       2 x = input("enter index")
# ----> 3 list4.remove(x)
#       4 print(list4)
#
# ValueError: list.remove(x): x not in list

# %%
#dictionary
dict = {"key1":12.5, "key2":"val2", "key3":"python", 4:[1,2,3,4]}
dict["key1"]=15
dict
# Out:
# {'key1': 15, 'key2': 'val2', 'key3': 'python', 4: [1, 2, 3, 4]}

# %%
num1 = int(input("Enter num1: "))
num2 = int(input("Enter num2: "))

add = num1 + num2
print("Addition:", add)

subt = num1 - num2
print("Subtraction:", subt)

mult = num1 * num2
print("Multiplication:", mult)

div = num1 / num2
print("Division:", div)
# Out:
# Addition: 12
# Subtraction: 8
# Multiplication: 20
# Division: 5.0

# %%
degree = int(input("Enter the mark: "))

if degree < 0 or degree > 100:
    print("Invalid mark! Please enter a value between 0 and 100.")
else:   
    if degree >= 90 and degree <= 100:
        print("Grade is A")
    elif degree >= 80 and degree <= 90:
        print("Grade is B")
    elif degree >= 70 and degree <= 80:
        print("Grade is C")
    elif degree >= 60 and degree <= 70:
        print("Grade is D")
    else:  
        print("Fail")
# Out:
# Grade is A

# %%
for i in range(5):
    if i == 2:
        continue
    else:
        print(i)
# Out:
# 0
# 1
# 3
# 4
