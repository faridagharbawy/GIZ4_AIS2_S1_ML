# %%
import pandas as pd

# %%
s  = pd.Series([1,2,3,4])
type(s)
s1= pd.Series([1,2,3,4], index = ['A','B','C','D'])

# %%
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data = [[1,444,'abc'],
        [2,555,'def'],
        [3,666,'ghi'],
        [4,444,'xyz']
        ]
data_2 = {'ID':[1,2,3,4],
          'std_id_dict':[444,555,666,444],
          'dept': ['abc','def','ghi', 'xyz']}


df = pd.DataFrame(data, columns=['ID','std_id', 'Dept'])
df
# Out:
#    ID  std_id Dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     444  xyz

# %%
df.columns
# Out:
# Index(['ID', 'std_id', 'Dept'], dtype='str')

# %%
index = ['row1', 'row2', 'row3','row4']
df.index = index 
display(df)
# Out:
#       ID  std_id Dept
# row1   1     444  abc
# row2   2     555  def
# row3   3     666  ghi
# row4   4     444  xyz

# %%
class person:
    def __init__(self, name):
        self.name = name
    @property   
    def getInfo(self):
        return f"my name is {self.name}"

# %%
p1 = person('George')
p1.getInfo
# Out:
# 'my name is George'

# %%
df.dtypes
# Out:
# ID        int64
# std_id    int64
# Dept        str
# dtype: object

# %%
df['Dept'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['Dept'] = df['Dept'].astype('category')
# df['Dept'].dtype

# %%
df.dtypes
# Out:
# ID           int64
# std_id       int64
# Dept      category
# dtype: object

# %%
df.tail(2)
# Out:
#       ID  std_id Dept
# row3   3     666  ghi
# row4   4     444  xyz

# %%
df.describe(include='category')
# Out:
#        Dept
# count     4
# unique    4
# top     abc
# freq      1

# %%
df.columns
# Out:
# Index(['ID', 'std_id', 'Dept'], dtype='str')

# %%
x = df['std_id'].unique().sum()
x
# Out:
# np.int64(1665)

# %%
df['std_id'].min()
# Out:
# np.int64(444)

# %%
df.Dept.idxmin()
# Out:
# 'row1'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, row1 to row4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      4 non-null      int64
#  1   std_id  4 non-null      int64
#  2   Dept    4 non-null      category
# dtypes: category(1), int64(2)
# memory usage: 304.0+ bytes

# %%
df['ID'].sum()
# Out:
# np.int64(10)

# %%
def duplicate(x):
    return x *2


df['std_id'].apply(lambda x : x*2)
# Out:
# row1     888
# row2    1110
# row3    1332
# row4     888
# Name: std_id, dtype: int64

# %%
df.iloc[2,1]
# Out:
# np.int64(666)

# %%
df.Dept.iloc[0:2]
# Out:
# row1    abc
# row2    def
# Name: Dept, dtype: category
# Categories (4, str): ['abc', 'def', 'ghi', 'xyz']

# %%
num_col = df.iloc[:, :-1]
target_y  = df.iloc[:,-1:]
num_col
# Out:
#       ID  std_id
# row1   1     444
# row2   2     555
# row3   3     666
# row4   4     444

# %%
df['new_col'] = df['std_id'] + df.ID
df
# Out:
#       ID  std_id Dept  new_col
# row1   1     444  abc      445
# row2   2     555  def      557
# row3   3     666  ghi      669
# row4   4     444  xyz      448

# %%
import numpy as np

# %%
data = [[1,444,'abc'],
        [2,555,'def'],
        [3,666,'ghi'],
        [4,"np.NAN",'xyz']
        ]

df = pd.DataFrame(data, columns=['ID','std_id', 'Dept'])
df
# Out:
#    ID  std_id Dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4  np.NAN  xyz

# %%
def isNull(df):
    null = df.isnull().sum()
    return pd.DataFrame(null).T

# %%
null = df.isnull().sum()
pd.DataFrame(null).T
# Out:
#    ID  std_id  Dept
# 0   0       0     0

# %%
# from isnullval import  isNull
# isNull(df)

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(["PassengerId", "Name", "Ticket"],axis= 1 ,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
dtypes = df.dtypes
n_unique = df.nunique()
pd.DataFrame({"Dtype":dtypes, "num_unique":n_unique}).T
# Out:
#            Survived Pclass  Sex      Age  SibSp  Parch     Fare Cabin Embarked
# Dtype         int64  int64  str  float64  int64  int64  float64   str      str
# num_unique        2      3    2       88      7      7      248   147        3

# %%
# from preprocessing.chk_t import chk_type
# chk_type(df)

# %%
cols = ['Survived','Pclass','Sex','SibSp','Parch','Embarked']
df[cols] = df[cols].astype('category')

# %%
def handle_types(cols):
    df[cols] = df[cols].astype('category')
    chk_type(df)

# %%
# from preprocessing.chk_t import chk_type

# %%
df.shape[0]
# Out:
# 891

# %%
null  =df.isnull().sum()
ratio = null /df.shape[0]
pd.DataFrame({"Null":null, "Ratio":ratio}).T
# Out:
#        Survived  Pclass  Sex         Age  SibSp  Parch  Fare       Cabin  \
# Null        0.0     0.0  0.0  177.000000    0.0    0.0   0.0  687.000000
# Ratio       0.0     0.0  0.0    0.198653    0.0    0.0   0.0    0.771044
#
#        Embarked
# Null   2.000000
# Ratio  0.002245

# %%
df = df.dropna(subset=['Embarked'])

# %%
df = df.drop('Cabin', axis= 1 )

# %%
median = df['Age'].median()
df['Age'].fillna(median, inplace= True)
# Out:
# C:\Users\Zone\AppData\Local\Temp\ipykernel_16424\3378742486.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(median, inplace= True)
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# ...

# %%
null  =df.isnull().sum()
ratio = null /df.shape[0]
pd.DataFrame({"Null":null, "Ratio":ratio}).T
# Out:
#        Survived  Pclass  Sex       Age  SibSp  Parch  Fare  Embarked
# Null        0.0     0.0  0.0  177.0000    0.0    0.0   0.0       0.0
# Ratio       0.0     0.0  0.0    0.1991    0.0    0.0   0.0       0.0

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df.dtypes
# Out:
# Survived    category
# Pclass      category
# Sex         category
# Age          float64
# SibSp       category
# Parch       category
# Fare         float64
# Embarked    category
# dtype: object

# %%
num_cols = ['Age','Fare']

# %%
num_cols = df.select_dtypes('number').columns
plt.figure(figsize=(8,1))
for i , col in enumerate(num_cols):
    plt.subplot(1,2, i+1)
    sns.boxplot(df[col], orient='h')

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3- Q1
    Lower_Fence = Q1 - 1.5*IQR
    Upper_Fence = Q3 + 1.5*IQR
    Lower_Outliers = df[df[col] < Lower_Fence][col].values
    Upper_Outliers = df[df[col] > Upper_Fence][col].values
    
    df[col].replace(Lower_Outliers, Lower_Fence, inplace=True)
    df[col].replace(Upper_Outliers, Upper_Fence, inplace=True)
# Out:
# C:\Users\Zone\AppData\Local\Temp\ipykernel_16424\2881739099.py:10: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col].replace(Lower_Outliers, Lower_Fence, inplace=True)
# ...

# %%
num_cols = df.select_dtypes('number').columns
plt.figure(figsize=(8,1))
for i , col in enumerate(num_cols):
    plt.subplot(1,2, i+1)
    sns.boxplot(df[col], orient='h')
    plt.title(f"{col} boxplot")
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(111)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#numerical
num_cols = df.select_dtypes('number').columns
plt.figure(figsize=(8,1))
for i , col in enumerate(num_cols):
    plt.subplot(1,2, i+1)
    sns.kdeplot(df[col])
    plt.title(f"{col} boxplot")
plt.show()

# %%
cat_cols = df.select_dtypes('category').columns
cat_cols
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='str')

# %%
cat_cols = df.select_dtypes('category').columns
plt.figure(figsize=(14,4))
for i , col in enumerate(cat_cols):
    plt.subplot(2,3, i+1)
    sns.countplot(x = col, data = df)
    plt.title(f"{col} boxplot")
plt.show()

# %%
#categorical
plt.figure(figsize=(14,4))
for i, col in enumerate(cat_cols):
    plt.subplot(2, 3, i+1)
    sns.countplot(x = col, data = df)
    plt.title(f"{col} Distribution Graph")

plt.show()

# %%
#pie chart
plt.figure(figsize=(9,4))
for i, col in enumerate(cat_cols):
    plt.subplot(2, 3, i+1)
    unique = df['Survived'].value_counts()
    count = unique.values
    categories = unique.index
    plt.pie(count, labels = categories, startangle = 140, autopct = '%1.1d%%')
    plt.title(f"{col} Pie Graph")            
# plt.subplots_adjust(hspace=30, wspace=30)
plt.show()

# %%
plt.figure(figsize=(2,2))
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[404], line 2
#       1 plt.figure(figsize=(2,2))
# ----> 2 plt.scatter()
#
# File d:\depi\GIZ4_AIS2_S1_ML\.env\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
sns.pairplot(df)

# %%
corr = df.select_dtypes(include = 'number').corr()
corr
# Out:
#            Age      Fare
# Age   1.000000  0.090985
# Fare  0.090985  1.000000

# %%
agg = df.pivot_table(index = 'Survived', columns = 'Sex', values = 'Age', aggfunc = len)
agg
# Out:
# Sex       female  male
# Survived
# 0             76   382
# 1            214   106

# %%
sns.heatmap(agg)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# ##### htat ML ta2sem data > the normalization > then encoding
# ### ba2sm eldata zy mna aayza x,y

# %%
x = df.drop('Survived', axis = 1) #yshel el survived
y = df['Survived']

# %%
x
# Out:
#     Pclass     Sex   Age SibSp Parch     Fare Embarked
# 0        3    male  22.0     1     0   7.2500        S
# 1        1  female  38.0     1     0  71.2833        C
# 2        3  female  26.0     0     0   7.9250        S
# 3        1  female  35.0     1     0  53.1000        S
# 4        3    male  35.0     0     0   8.0500        S
# ..     ...     ...   ...   ...   ...      ...      ...
# 885      3  female  39.0     0     5  29.1250        Q
# 887      1  female  19.0     0     0  30.0000        S
# 888      3  female   NaN     1     2  23.4500        S
# 889      1    male  26.0     0     0  30.0000        C
# 890      3    male  32.0     0     0   7.7500        Q
#
# [778 rows x 7 columns]

# %% [markdown]
# #### normalization > bgm3 dist el data fe mkan gamb baado
# #### ex1 of norm > min-max >     (X - min) / (max - min) >>> by2sm ala el distance kolo
# #### ex2 of norm > standardization
#
# #### fit > ageb elmaaloma ahotha fgeby (mathematic results bto3 el hagat > mean/variance,,,)
# #### transform > aapply elhagat de
# #### fit-transform > both byt3mlo

# %% [markdown]
# ### data leakage > b3lm el data w bahfaz el test

# %%
from sklearn.preprocessing import MinMaxScaler
num_cols = x.select.dtypes('number').column
scaler = MinMaxScaler()
scaler.fit(x[num_cols])
x[num_cols] = scaler.transform(x[num_cols])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[343], line 1
# ----> 1 from sklearn.preprocessing import MinMaxScaler
#       2 num_cols = x.select.dtypes('number').column
#       3 scaler = MinMaxScaler()
#
# ModuleNotFoundError: No module named 'sklearn'
